# %%
import numpy as np
import pandas as pd

# %%
credits_df = pd.read_csv('../Data/tmdb_5000_credits.csv')
credits_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movies_df = pd.read_csv('../Data/tmdb_5000_movies.csv')
movies_df.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
# ...

# %%
cel_phones = pd.read_json('../Data/Cell_Phones_and_Accessories_5.json', lines=True)
cel_phones.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        5      True   08 4, 2014  A24E3SXTC62LJI  7508492919
# 1        5      True  02 12, 2014  A269FLZCB4GIPV  7508492919
# 2        3      True   02 8, 2014   AB6CHQWHZW4TV  7508492919
# 3        2      True   02 4, 2014   A1M117A53LEI8  7508492919
# 4        4      True   02 3, 2014  A272DUT8M88ZS8  7508492919
#
#                   style      reviewerName  \
# 0  {'Color:': ' Bling'}  Claudia Valdivia
# 1                   NaN       sarah ponce
# 2                   NaN               Kai
# 3                   NaN   Sharon Williams
# 4                   NaN   Bella Rodriguez
#
#                                           reviewText  \
# 0  Looks even better in person. Be careful to not...
# 1  When you don't want to spend a whole lot of ca...
# 2  so the case came on time, i love the design. I...
# 3  DON'T CARE FOR IT.  GAVE IT AS A GIFT AND THEY...
# 4  I liked it because it was cute, but the studs ...
#
# ...

# %%
meta_cel_phones = pd.read_json('../Data/meta_Cell_Phones_and_Accessories.json', lines=True)
meta_cel_phones.head()
# Out:
#                                             category tech1  \
# 0  [Cell Phones & Accessories, Accessories, Scree...
# 1  [Cell Phones & Accessories, Accessories, Car A...
# 2  [Cell Phones & Accessories, Cases, Holsters & ...
# 3  [Cell Phones & Accessories, Cases, Holsters & ...
# 4  [Cell Phones & Accessories, Cases, Holsters & ...
#
#                                          description fit  \
# 0                                                 []
# 1                                                 []
# 2  [New items to give you a new good mood, welcom...
# 3  [A brand-new, unused, unopened, undamaged item...
# 4  [A brand-new, unused, unopened, undamaged item...
#
#                                                title also_buy image tech2  \
# 0                     Trollies Sing a Long Party VHS       []    []
# 1                                        La Pura VHS       []    []
# 2  Leopard Thanksgiving Easter PC Black Case for ...       []    []
# ...

# %%
meta_cel_phones.title
# Out:
# 0                            Trollies Sing a Long Party VHS
# 1                                               La Pura VHS
# 2         Leopard Thanksgiving Easter PC Black Case for ...
# 3         Puppies Faceplate Hard Case Protector for Net1...
# 4         White Wolf Faceplate Protector Hard Case for S...
#                                 ...
# 590066    Full LCD Touch Screen Digitizer Assembly Repla...
# 590067    Universal Sports Armband Casehigh Shop Easy Fi...
# 590068    iPhone 6 Plus Case, LoHi iPhone 6s Plus Case [...
# 590069    Universal Sports Armband Casehigh Shop Easy Fi...
# 590070    Case For Samsung Galaxy S7 Edge, CoverProof Ti...
# Name: title, Length: 590071, dtype: object

# %%
mobile_df = pd.read_excel('../Data/mobile_phone_names.xlsx')
mobile_df.head(3)
# Out:
#               hideModel  Unnamed: 1  Unnamed: 2  Unnamed: 3
# 0      Huawei nova 8 5G         NaN         NaN         NaN
# 1  Huawei nova 8 Pro 5G         NaN         NaN         NaN
# 2             Honor V40         NaN         NaN         NaN

# %%
mobile_list = [_ for _ in mobile_df.iloc[:,0] if type(_) == str ]
mobile_list
# Out:
# ['Huawei nova 8 5G',
#  'Huawei nova 8 Pro 5G',
#  'Honor V40',
#  'Oppo Find X3 Neo',
#  'Oppo Find X3',
#  'Oppo Find X3 Pro',
#  'OnePlus 9',
#  'OnePlus 9 Pro',
#  'Realme GT 5G',
#  'Moto G100',
#  'Samsung Galaxy S21',
#  'Samsung Galaxy S21+',
#  'Samsung Galaxy S21 Ultra',
#  'Xiaomi Mi 11',
#  'Xiaomi Mi 11 Pro',
#  'Xiaomi Mi 11 Ultra',
#  'Redmi K40',
#  'Redmi K40 Pro',
#  'Redmi K40 Pro+',
#  'Redmi Note 10',
#  'Redmi Note 10S',
#  'Redmi Note 10 5G',
#  'Redmi Note 10 Pro',
#  'Realme 8',
#  'Realme 8 Pro',
#  'Meizu 18',
#  'Meizu 18 Pro',
#  'Vivo iQOO Neo5',
#  'Vivo iQOO 7',
#  'Vivo X60',
#  'Vivo X60 Pro',
#  'Vivo X60 Pro+',
#  'Asus\xa0ROG Phone 5',
#  'Asus ROG Phone 5 Pro',
#  'Asus ROG Phone 5 Ultimate',
#  'Xiaomi Black Shark 4',
#  'Xiaomi Black Shark 4 Pro',
#  'ZTE Nubia Red Magic 6',
#  'ZTE Nubia Red Magic 6 Pro',
#  'Meizu 17 Pro',
#  'Meizu 17',
#  'Huawei nova 7 Pro 5G',
#  'Huawei nova 7 5G',
#  'Huawei nova 7 SE',
#  'Honor 30 Pro+',
# ...

# %%
import re

mobile_list_updated = []
for string in mobile_list:
    mobile_list_updated.append(re.sub('<.*?>', '', string))

# %%
mobile_list_updated
# Out:
# ['Huawei nova 8 5G',
#  'Huawei nova 8 Pro 5G',
#  'Honor V40',
#  'Oppo Find X3 Neo',
#  'Oppo Find X3',
#  'Oppo Find X3 Pro',
#  'OnePlus 9',
#  'OnePlus 9 Pro',
#  'Realme GT 5G',
#  'Moto G100',
#  'Samsung Galaxy S21',
#  'Samsung Galaxy S21+',
#  'Samsung Galaxy S21 Ultra',
#  'Xiaomi Mi 11',
#  'Xiaomi Mi 11 Pro',
#  'Xiaomi Mi 11 Ultra',
#  'Redmi K40',
#  'Redmi K40 Pro',
#  'Redmi K40 Pro+',
#  'Redmi Note 10',
#  'Redmi Note 10S',
#  'Redmi Note 10 5G',
#  'Redmi Note 10 Pro',
#  'Realme 8',
#  'Realme 8 Pro',
#  'Meizu 18',
#  'Meizu 18 Pro',
#  'Vivo iQOO Neo5',
#  'Vivo iQOO 7',
#  'Vivo X60',
#  'Vivo X60 Pro',
#  'Vivo X60 Pro+',
#  'Asus\xa0ROG Phone 5',
#  'Asus ROG Phone 5 Pro',
#  'Asus ROG Phone 5 Ultimate',
#  'Xiaomi Black Shark 4',
#  'Xiaomi Black Shark 4 Pro',
#  'ZTE Nubia Red Magic 6',
#  'ZTE Nubia Red Magic 6 Pro',
#  'Meizu 17 Pro',
#  'Meizu 17',
#  'Huawei nova 7 Pro 5G',
#  'Huawei nova 7 5G',
#  'Huawei nova 7 SE',
#  'Honor 30 Pro+',
# ...

# %%
new_df = pd.DataFrame()
new_df['model_name'] = mobile_list_updated
new_df
# Out:
#                  model_name
# 0          Huawei nova 8 5G
# 1      Huawei nova 8 Pro 5G
# 2                 Honor V40
# 3          Oppo Find X3 Neo
# 4              Oppo Find X3
# ..                      ...
# 220       Xiaomi Mi CC9 Pro
# 221         ZTE Axon 10 Pro
# 222   ZTE Nubia Red Magic 3
# 223  ZTE Nubia Red Magic 3S
# 224           ZTE Nubia Z20
#
# [225 rows x 1 columns]

# %%
new_df.to_csv('mobile_data.csv')
