# %%
import requests
import re
from bs4 import BeautifulSoup

# %%
web_url = 'https://en.wikipedia.org/wiki/Comparison_of_smartphones'

# %%
# Session helps to object allows you to persist certain parameters across requests
# By default, Request will keep waiting for a response indefinitely. Therefore, it is advised to set the timeout parameter.
# If the request was successful, you should see the reponse output as '200'.
s = requests.Session()
response = s.get(web_url, timeout=10)
#response2 = s.get(url2, timeout=5)
response
# Out:
# <Response [200]>

# %%
# parse response content to html
soup = BeautifulSoup(response.content, 'html.parser')

# %%
# to view the content in html format
pretty_soup = soup.prettify()

# %%
# title of Wikipedia page
soup.title.string
# Out:
# 'Comparison of smartphones - Wikipedia'

# %%
info_table = soup.find_all('table')
# wikitable sortable collapsible mw-collapsible mw-made-collapsible jquery-tablesorter
# wikitable sortable collapsible mw-collapsible mw-made-collapsible jquery-tablesorter

# %%
right_table=soup.find('table', {"class":'wikitable sortable collapsible'})

# %%
right_table
# Out:
# <table class="wikitable sortable collapsible" data-sort-type="number">
# <tbody><tr>
# <th>Model
# </th>
# <th><a href="/wiki/System_on_a_chip" title="System on a chip">SoC</a>
# </th>
# <th data-sort-type="number"><a href="/wiki/Central_processing_unit" title="Central processing unit">CPU</a> specifications
# </th>
# <th data-sort-type="number"><a href="/wiki/Graphics_processing_unit" title="Graphics processing unit">GPU</a>
# </th>
# <th><a href="/wiki/Flash_memory" title="Flash memory">Storage capacity</a>
# </th>
# <th><a href="/wiki/Memory_card" title="Memory card">Removable storage</a>
# </th>
# <th data-sort-type="number"><a href="/wiki/Random-access_memory" title="Random-access memory">RAM</a>
# </th>
# <th><a href="/wiki/Operating_system" title="Operating system">OS</a>
# </th>
# <th data-sort-type="number">Custom launcher
# </th>
# <th>Dimensions
# </th>
# <th>Weight
# </th>
# <th><a href="/wiki/Lithium-ion_battery" title="Lithium-ion battery">Battery</a>
# </th>
# <th><a href="/wiki/Rechargeable_battery" title="Rechargeable battery">Charging</a>
# </th>
# <th><a href="/wiki/Display_resolution" title="Display resolution">Display</a>
# </th>
# <th><a href="/wiki/Camera_phone" title="Camera phone">Camera</a>
# </th>
# <th><a href="/wiki/Video" title="Video">Video</a>
# </th>
# <th><a href="/wiki/Front-facing_camera" title="Front-facing camera">Front-facing camera</a>
# </th>
# <th><a href="/wiki/Fingerprint_scanner" title="Fingerprint scanner">Fingerprint scanner</a>
# </th>
# <th><a href="/wiki/Facial_recognition_system" title="Facial recognition system">Facial recognition</a>
# </th></tr>
# <tr>
# <td>Huawei nova 8 5G
# </td>
# <td rowspan="2"><a href="/wiki/HiSilicon" title="HiSilicon">HiSilicon Kirin 985 5G</a>
# </td>
# <td rowspan="2">Octa-core, (1x 2.58<span class="nowrap"> </span>GHz Cortex-A76 + 3x 2.40<span class="nowrap"> </span>GHz Cortex-A76 + 4x 1.84<span class="nowrap"> </span>GHz Cortex-A55)
# </td>
# <td rowspan="2"><a href="/wiki/Mali_(GPU)" title="Mali (GPU)">Mali</a>-G77 (8-core)
# </td>
# <td rowspan="2">128/256 GB
# </td>
# <td rowspan="2">None
# </td>
# <td rowspan="3">8 GB
# </td>
# <td rowspan="3"><a href="/wiki/Android_10" title="Android 10">Android 10</a>
# </td>
# <td rowspan="2"><a href="/wiki/EMUI" title="EMUI">EMUI</a> 11
# </td>
# <td>160.1 x 74.1 x 7.6 mm
# </td>
# <td>169 g
# </td>
# <td>3800 mAh
# </td>
# <td rowspan="2"><a href="/wiki/USB-C" title="USB-C">USB-C</a>, <br/> 66 W
# </td>
# <td>6.57", 2340×1080, 90 Hz <a href="/wiki/OLED" title="OLED">OLED</a>
# </td>
# <td rowspan="2">64 MP (wide) + 8 MP (ultrawide) + 2x 2 MP (depth and macro)
# </td>
# <td rowspan="2">4K, 1080p, 720p@960fps
# </td>
# <td>32 MP
# </td>
# <td rowspan="3">Optical
# </td>
# <td rowspan="3">Yes
# </td></tr>
# <tr>
# <td>Huawei nova 8 Pro 5G
# </td>
# <td>163.3 x 74.1 x 7.9 mm
# </td>
# <td>184 g
# </td>
# <td rowspan="2">4000 mAh
# </td>
# <td rowspan="2">6.72", 2676×1236, 120 Hz OLED
# </td>
# <td>16 MP (wide) + 32 MP (ultrawide)
# </td></tr>
# <tr>
# <td>Honor V40
# </td>
# <td><a href="/wiki/List_of_MediaTek_processors" title="List of MediaTek processors">MediaTek Dimensity 1000+</a>
# </td>
# <td>Octa-core, (4x 2.6<span class="nowrap"> </span>GHz Cortex-A77 + 4x 2.0<span class="nowrap"> </span>GHz Cortex-A55)
# </td>
# <td>Mali-G77 MC9
# </td>
# <td>128/256 GB
# </td>
# <td>None
# </td>
# <td>Magic UI 4.0
# </td>
# <td>163.1 x 74.3 x 8 mm
# </td>
# <td>189 g
# </td>
# <td>USB-C, <br/> 66 W
# <p>Wireless, <br/> 50 W
# </p>
# </td>
# <td>50 MP (wide) + 8 MP (ultrawide) + 2 MP (macro)
# </td>
# <td>4K@30/60fps, 1080p@30/60fps
# </td>
# <td>16 MP
# </td></tr>
# <tr>
# <td>Oppo Find X3 Neo
# </td>
# <td><a href="/wiki/List_of_Qualcomm_Snapdragon_processors" title="List of Qualcomm Snapdragon processors">Qualcomm Snapdragon 865</a>
# </td>
# <td>Octa-core, (1x 2.84<span class="nowrap"> </span>GHz + 3x 2.42<span class="nowrap"> </span>GHz + 4x 1.80<span class="nowrap"> </span>GHz Kryo 585)
# </td>
# <td rowspan="2">Adreno 650
# </td>
# <td>256 GB
# </td>
# <td rowspan="3">None
# </td>
# <td>12 GB
# </td>
# <td rowspan="3">Android 11
# </td>
# <td rowspan="3"><a class="mw-redirect" href="/wiki/Color_OS" title="Color OS">Color OS</a> 11
# </td>
# <td>159.9 x 72.5 x 8 mm
# </td>
# <td>184 g
# </td>
# <td rowspan="3">4500 mAh
# </td>
# <td>USB-C, <br/> 65 W
# </td>
# <td>6.55", 2400×1080, 90 Hz AMOLED
# </td>
# <td>50 MP (wide) + 13 MP (telephoto) + 16 MP (ultrawide) + 2 MP (macro)
# </td>
# <td>4K@30/60fps, 1080p@30/60fps
# </td>
# <td rowspan="3">32 MP
# </td>
# <td rowspan="3">Optical
# </td>
# <td rowspan="3">Yes
# </td></tr>
# <tr>
# <td><a href="/wiki/Oppo_Find_X3" title="Oppo Find X3">Oppo Find X3</a>
# </td>
# <td><a href="/wiki/List_of_Qualcomm_Snapdragon_processors" title="List of Qualcomm Snapdragon processors">Qualcomm Snapdragon 870</a>
# </td>
# <td>Octa-core, (1x 3.2<span class="nowrap"> </span>GHz + 3x 2.42<span class="nowrap"> </span>GHz + 4x 1.80<span class="nowrap"> </span>GHz Kryo 585)
# </td>
# <td>128/256 GB
# </td>
# <td>8 GB
# </td>
# <td rowspan="2">163.6 x 74 x 8.3 mm
# </td>
# <td rowspan="2">193 g
# </td>
# <td rowspan="2">USB-C, <br/> 65 W
# <p>Wireless, <br/> 30 W
# </p>
# </td>
# <td rowspan="2">6.7", 3216×1440, 120 Hz AMOLED
# </td>
# <td rowspan="2">50 MP (wide) + 13 MP (telephoto) + 50 MP (ultrawide) + 3 MP (macro)
# </td>
# <td rowspan="2">4K@30/60fps, 1080p@30/60/240fps
# </td></tr>
# <tr>
# <td>Oppo Find X3 Pro
# </td>
# <td><a href="/wiki/List_of_Qualcomm_Snapdragon_processors" title="List of Qualcomm Snapdragon processors">Qualcomm Snapdragon 888</a>
# </td>
# <td>Octa-core, (1x 2.84<span class="nowrap"> </span>GHz + 3x 2.42<span class="nowrap"> </span>GHz + 4x 1.80<span class="nowrap"> </span>GHz Kryo 680)
# </td>
# <td>Adreno 660
# </td>
# <td>256 GB
# </td>
# <td>8/12 GB
# </td></tr>
# <tr>
# <td><a href="/wiki/OnePlus_9" title="OnePlus 9">OnePlus 9</a>
# </td>
# <td rowspan="2"><a href="/wiki/List_of_Qualcomm_Snapdragon_processors" title="List of Qualcomm Snapdragon processors">Qualcomm Snapdragon 888</a>
# </td>
# <td rowspan="2">Octa-core, (1x 2.84<span class="nowrap"> </span>GHz + 3x 2.42<span class="nowrap"> </span>GHz + 4x 1.80<span class="nowrap"> </span>GHz Kryo 680)
# </td>
# <td rowspan="2">Adreno 660
# </td>
# <td rowspan="2">128/256 GB
# </td>
# <td rowspan="2">None
# </td>
# <td rowspan="2">8/12 GB
# </td>
# <td rowspan="2">Android 11
# </td>
# <td rowspan="2"><a href="/wiki/OxygenOS" title="OxygenOS">OxygenOS</a> 11
# </td>
# <td>160 x 74.2 x 8.7 mm
# </td>
# <td>192 g
# </td>
# <td rowspan="2">4500 mAh
# </td>
# <td>USB-C, <br/> 65 W
# <p>Wireless, <br/> 15 W
# </p>
# </td>
# <td>6.55", 2400×1080, 120 Hz AMOLED
# </td>
# <td>48 MP (wide) + 50 MP (ultrawide) + 2 MP (depth)
# </td>
# <td>8K@30fps, 4K@30/60fps, 1080p@30/60/240fps
# </td>
# <td rowspan="2">16 MP
# </td>
# <td rowspan="2">Optical
# </td>
# <td rowspan="2">Yes
# </td></tr>
# <tr>
# <td>OnePlus 9 Pro
# </td>
# <td>163.2 x 73.6 x 8.7 mm
# </td>
# <td>197 g
# </td>
# <td>USB-C, <br/> 65 W
# <p>Wireless, <br/> 50 W
# </p>
# </td>
# <td>6.7", 3216×1440, 120 Hz AMOLED
# </td>
# <td>48 MP (wide) + 50 MP (ultrawide) + 8 MP (telephoto) + 2 MP (depth)
# </td>
# <td>8K@30fps, 4K@30/60/120fps, 1080p@30/60/240fps
# </td></tr>
# <tr>
# <td>Realme GT 5G
# </td>
# <td><a href="/wiki/List_of_Qualcomm_Snapdragon_processors" title="List of Qualcomm Snapdragon processors">Qualcomm Snapdragon 888</a>
# </td>
# <td>Octa-core, (1x 2.84<span class="nowrap"> </span>GHz + 3x 2.42<span class="nowrap"> </span>GHz + 4x 1.80<span class="nowrap"> </span>GHz Kryo 680)
# </td>
# <td>Adreno 660
# </td>
# <td>128/256 GB
# </td>
# <td>None
# </td>
# <td>8/12 GB
# </td>
# <td>Android 11
# </td>
# <td>Realme UI 2.0
# </td>
# <td>158.5 x 73.3 x 8.4 mm
# </td>
# <td>186 g
# </td>
# <td>4500 mAh
# </td>
# <td>USB-C, <br/> 65 W
# </td>
# <td>6.43", 2400×1080, 120 Hz AMOLED
# </td>
# <td>64 MP (wide) + 8 MP (ultrawide) + 2 MP (macro)
# </td>
# <td>4K@30/60fps, 1080p@30/60/240fps
# </td>
# <td>16 MP
# </td>
# <td>Optical
# </td>
# <td>Yes
# </td></tr>
# <tr>
# <td>Moto G100
# </td>
# <td><a href="/wiki/List_of_Qualcomm_Snapdragon_processors" title="List of Qualcomm Snapdragon processors">Qualcomm Snapdragon 870</a>
# </td>
# <td>Octa-core, (1x 3.2<span class="nowrap"> </span>GHz + 3x 2.42<span class="nowrap"> </span>GHz + 4x 1.80<span class="nowrap"> </span>GHz Kryo 585)
# </td>
# <td>Adreno 650
# </td>
# <td>128 GB
# </td>
# <td>microSDXC, up to 512 GB
# </td>
# <td>8 GB
# </td>
# <td>Android 11
# </td>
# <td class="table-na" data-sort-value="" style="background: #ececec; color: #2C2C2C; vertical-align: middle; text-align: center;">N/A
# </td>
# <td>168.4 x 74 x 9.7 mm
# </td>
# <td>207 g
# </td>
# <td>5000 mAh
# </td>
# <td>USB-C, <br/> 20 W
# </td>
# <td>6.7", 2520×1080, 90 Hz IPS LCD
# </td>
# <td>64 MP (wide) + 16 MP (ultrawide) + 2 MP (depth) + ToF 3D
# </td>
# <td>6K@30fps, 4K@30/60fps, 1080p@30/60/120fps
# </td>
# <td>16 MP (wide) + 8 MP (ultrawide)
# </td>
# <td>Side-mounted
# </td>
# <td>Yes
# </td></tr>
# <tr>
# <td><a href="/wiki/Samsung_Galaxy_S21" title="Samsung Galaxy S21">Samsung Galaxy S21</a>
# </td>
# <td rowspan="3">Exynos 2100 <br/> Qualcomm Snapdragon 888
# </td>
# <td rowspan="3">Octa-core,
# <p><b>Exynos</b>: (1x 2.9<span class="nowrap"> </span>GHz Cortex-X1 + 3x 2.8<span class="nowrap"> </span>GHz Cortex-A78 + 4x 2.2<span class="nowrap"> </span>GHz Cortex-A55)
# </p><p><b>Snapdragon</b>: (1x 2.84<span class="nowrap"> </span>GHz + 3x 2.42<span class="nowrap"> </span>GHz + 4x 1.8<span class="nowrap"> </span>GHz Kryo 680)
# </p>
# </td>
# <td rowspan="3"><b>Exynos</b>: Mali-G78 MP14
# <p><b>Snapdragon</b>: Adreno 660
# </p>
# </td>
# <td rowspan="2">128/256 GB
# </td>
# <td rowspan="3">None
# </td>
# <td rowspan="2">8 GB
# </td>
# <td rowspan="3">Android 11
# </td>
# <td rowspan="3"><a href="/wiki/One_UI" title="One UI">One UI</a> 3.1
# </td>
# <td>151.7 x 71.2 x 7.9 mm
# </td>
# <td>169 g
# </td>
# <td>4000 mAh
# </td>
# <td rowspan="3">USB-C, <br/> 25 W
# <p><a href="/wiki/Inductive_charging" title="Inductive charging">Wireless</a>, <br/> 15 W
# </p>
# </td>
# <td>6.2", 2400×1080, 120 Hz AMOLED
# </td>
# <td rowspan="2">12 MP (wide) + 64 MP (telephoto) + 12 MP (ultrawide)
# </td>
# <td rowspan="3">8K@24fps, 4K@30/60fps, 1080p@30/60/240fps, 720p@960fps
# </td>
# <td rowspan="2">10 MP
# </td>
# <td rowspan="3">Ultrasonic
# </td>
# <td rowspan="3">Yes
# </td></tr>
# <tr>
# <td>Samsung Galaxy S21+
# </td>
# <td>161.5 x 75.6 x 7.8 mm
# </td>
# <td>200 g
# </td>
# <td>4800 mAh
# </td>
# <td>6.7", 2400×1080, 120 Hz AMOLED
# </td></tr>
# <tr>
# <td>Samsung Galaxy S21 Ultra
# </td>
# <td>128/256/512 GB
# </td>
# <td>12/16 GB
# </td>
# <td>165.1 x 75.6 x 8.9 mm
# </td>
# <td>227 g
# </td>
# <td>5000 mAh
# </td>
# <td>6.8", 3200×1440, 120 Hz AMOLED
# </td>
# <td>108 MP (wide) + 2x 10 MP (telephoto) + 12 MP (ultrawide)
# </td>
# <td>40 MP
# </td></tr>
# <tr>
# <td><a href="/wiki/Xiaomi_Mi_11" title="Xiaomi Mi 11">Xiaomi Mi 11</a>
# </td>
# <td rowspan="3"><a href="/wiki/List_of_Qualcomm_Snapdragon_processors" title="List of Qualcomm Snapdragon processors">Qualcomm Snapdragon 888</a>
# </td>
# <td rowspan="3">Octa-core, (1x 2.84<span class="nowrap"> </span>GHz + 3x 2.42<span class="nowrap"> </span>GHz + 4x 1.80<span class="nowrap"> </span>GHz Kryo 680)
# </td>
# <td rowspan="3">Adreno 660
# </td>
# <td rowspan="2">128/256 GB
# </td>
# <td rowspan="3">None
# </td>
# <td rowspan="3">8/12 GB
# </td>
# <td rowspan="3"><a href="/wiki/Android_11" title="Android 11">Android 11</a>
# </td>
# <td rowspan="3"><a href="/wiki/MIUI" title="MIUI">MIUI</a> 12
# </td>
# <td>164.3 x 74.6 x 8.1 mm
# </td>
# <td>196 g
# </td>
# <td>4600 mAh
# </td>
# <td>USB-C, <br/> 55 W
# <p><a href="/wiki/Inductive_charging" title="Inductive charging">Wireless</a>, <br/> 50 W
# </p>
# </td>
# <td rowspan="3">6.8", 3200×1440, 120 Hz AMOLED
# </td>
# <td>108 MP (wide) + 13 MP (ultrawide) + 5 MP (macro)
# </td>
# <td>8K@24/30fps, 4K@30/60fps, 1080p@30/60/120/240/480fps
# </td>
# <td rowspan="3">20 MP
# </td>
# <td rowspan="3">Optical
# </td>
# <td rowspan="3">Yes
# </td></tr>
# <tr>
# <td>Xiaomi Mi 11 Pro
# </td>
# <td>164.3 x 74.6 x 8.5 mm
# </td>
# <td>208 g
# </td>
# <td rowspan="2">5000 mAh
# </td>
# <td rowspan="2">USB-C, <br/> 67 W
# <p>Wireless, <br/> 67 W
# </p>
# </td>
# <td>50 MP (wide) + 13 MP (ultrawide) + 8 MP (telephoto)
# </td>
# <td rowspan="2">8K@24fps, 4K@30/60fps, 1080p@30/60fps
# </td></tr>
# <tr>
# <td>Xiaomi Mi 11 Ultra
# </td>
# <td>256/512 GB
# </td>
# <td>164.3 x 74.6 x 8.4 mm
# </td>
# <td>234 g
# </td>
# <td>50 MP (wide) + 48 MP (ultrawide) + 48 MP (telephoto)
# </td></tr>
# <tr>
# <td><a href="/wiki/Redmi_K40" title="Redmi K40">Redmi K40</a>
# </td>
# <td><a href="/wiki/List_of_Qualcomm_Snapdragon_processors" title="List of Qualcomm Snapdragon processors">Qualcomm Snapdragon 870</a>
# </td>
# <td>Octa-core, (1x 3.2<span class="nowrap"> </span>GHz + 3x 2.42<span class="nowrap"> </span>GHz + 4x 1.80<span class="nowrap"> </span>GHz Kryo 585)
# </td>
# <td>Adreno 650
# </td>
# <td rowspan="2">128/256 GB
# </td>
# <td rowspan="3">None
# </td>
# <td>6/8/12 GB
# </td>
# <td rowspan="7">Android 11
# </td>
# <td rowspan="7">MIUI 12
# </td>
# <td rowspan="3">163.7 x 76.4 x 7.8 mm
# </td>
# <td rowspan="3">196 g
# </td>
# <td rowspan="3">4520 mAh
# </td>
# <td rowspan="3">USB-C, <br/> 33 W
# </td>
# <td rowspan="3">6.67", 2400×1080, 120 Hz AMOLED
# </td>
# <td>48 MP (wide) + 8 MP (ultrawide) + 5 MP (macro)
# </td>
# <td>4K@30fps, 1080p@30/60/120/240/960fps
# </td>
# <td rowspan="3">20 MP
# </td>
# <td rowspan="7">Side-mounted
# </td>
# <td rowspan="7">Yes
# </td></tr>
# <tr>
# <td>Redmi K40 Pro
# </td>
# <td rowspan="2"><a href="/wiki/List_of_Qualcomm_Snapdragon_processors" title="List of Qualcomm Snapdragon processors">Qualcomm Snapdragon 888</a>
# </td>
# <td rowspan="2">Octa-core, (1x 2.84<span class="nowrap"> </span>GHz + 3x 2.42<span class="nowrap"> </span>GHz + 4x 1.80<span class="nowrap"> </span>GHz Kryo 680)
# </td>
# <td rowspan="2">Adreno 660
# </td>
# <td>6/8 GB
# </td>
# <td>64 MP (wide) + 8 MP (ultrawide) + 5 MP (macro)
# </td>
# <td rowspan="2">8K@30fps, 4K@30/60fps, 1080p@30/60/120/240/960fps
# </td></tr>
# <tr>
# <td>Redmi K40 Pro+
# </td>
# <td>256 GB
# </td>
# <td>12 GB
# </td>
# <td>108 MP (wide) + 8 MP (ultrawide) + 5 MP (macro)
# </td></tr>
# <tr>
# <td>Redmi Note 10
# </td>
# <td><a href="/wiki/List_of_Qualcomm_Snapdragon_processors" title="List of Qualcomm Snapdragon processors">Qualcomm Snapdragon 678</a>
# </td>
# <td>Octa-core, (2x 2.20<span class="nowrap"> </span>GHz + 6x 1.70<span class="nowrap"> </span>GHz Kryo 460)
# </td>
# <td>Adreno 612
# </td>
# <td rowspan="4">64/128 GB
# </td>
# <td rowspan="4">microSDXC up to 512 GB
# </td>
# <td>4/6 GB
# </td>
# <td rowspan="2">160.5 x 74.5 x 8.3 mm
# </td>
# <td rowspan="2">179 g
# </td>
# <td rowspan="3">5000 mAh
# </td>
# <td rowspan="2">USB-C, <br/> 33 W
# </td>
# <td rowspan="2">6.43", 2400×1080, AMOLED
# </td>
# <td>48 MP (wide) + 8 MP (ultrawide) + 2 MP (macro) + 2 MP (depth)
# </td>
# <td>4K@30fps, 1080p@30/60fps
# </td>
# <td rowspan="2">13 MP
# </td></tr>
# <tr>
# <td>Redmi Note 10S
# </td>
# <td><a href="/wiki/List_of_MediaTek_processors#Helio_G_Series" title="List of MediaTek processors">MediaTek Helio G95</a>
# </td>
# <td>Octa-core, (2x 2.05<span class="nowrap"> </span>GHz Cortex-A76 + 6x 2.0<span class="nowrap"> </span>GHz Cortex-A55)
# </td>
# <td>Mali-G76 MC4
# </td>
# <td>6/8 GB
# </td>
# <td>64 MP (wide) + 8 MP (ultrawide) + 2 MP (macro) + 2 MP (depth)
# </td>
# <td>4K@30fps, 1080p@30/60/120fps, 720p@960fps
# </td></tr>
# <tr>
# <td>Redmi Note 10 5G
# </td>
# <td><a href="/wiki/List_of_MediaTek_processors#Dimensity_Series" title="List of MediaTek processors">MediaTek Dimensity 700</a>
# </td>
# <td>Octa-core, (4x 2.2<span class="nowrap"> </span>GHz Cortex-A76 + 4x 2.0<span class="nowrap"> </span>GHz Cortex-A55)
# </td>
# <td>Mali-G57 MC2
# </td>
# <td>4/6 GB
# </td>
# <td>161.8 x 75.3 x 8.9 mm
# </td>
# <td>190 g
# </td>
# <td>USB-C, <br/> 18 W
# </td>
# <td>6.5", 2400×1080, 90 Hz IPS LCD
# </td>
# <td>48 MP (wide) + 2 MP (macro) + 2 MP (depth)
# </td>
# <td>4K@30fps, 1080p@30/60/120fps
# </td>
# <td>8 MP
# </td></tr>
# <tr>
# <td>Redmi Note 10 Pro
# </td>
# <td><a href="/wiki/List_of_Qualcomm_Snapdragon_processors" title="List of Qualcomm Snapdragon processors">Qualcomm Snapdragon 732G</a>
# </td>
# <td>Octa-core, (2x 2.32<span class="nowrap"> </span>GHz + 6x 1.80<span class="nowrap"> </span>GHz Kryo 470)
# </td>
# <td>Adreno 618
# </td>
# <td>6/8 GB
# </td>
# <td>164 x 76.5 x 8.1 mm
# </td>
# <td>193 g
# </td>
# <td>5020 mAh
# </td>
# <td>USB-C, <br/> 33 W
# </td>
# <td>6.67", 2400×1080, 120 Hz AMOLED
# </td>
# <td>108 MP (wide) + 8 MP (ultrawide) + 5 MP (macro) + 2 MP (depth)
# </td>
# <td>4K@30fps, 1080p@30/60/120fps, 720p@960fps
# </td>
# <td>16 MP
# </td></tr>
# <tr>
# <td>Realme 8
# </td>
# <td><a href="/wiki/List_of_MediaTek_processors#Helio_G_Series" title="List of MediaTek processors">MediaTek Helio G95</a>
# </td>
# <td>Octa-core, (2x 2.05<span class="nowrap"> </span>GHz Cortex-A76 + 6x 2.0<span class="nowrap"> </span>GHz Cortex-A55)
# </td>
# <td>Mali-G76 MC4
# </td>
# <td rowspan="2">128 GB
# </td>
# <td rowspan="2">microSDXC up to 512 GB
# </td>
# <td>4/6/8 GB
# </td>
# <td rowspan="2">Android 11
# </td>
# <td rowspan="2">Realme UI 2.0
# </td>
# <td>160.6 x 73.9 x 8 mm
# </td>
# <td>177 g
# </td>
# <td>5000 mAh
# </td>
# <td>USB-C, <br/> 30 W
# </td>
# <td rowspan="2">6.4", 2400×1080, AMOLED
# </td>
# <td>64 MP (wide) + 8 MP (ultrawide) + 2 MP (macro) + 2 MP (depth)
# </td>
# <td>4K@30fps, 1080p@30/60/120fps
# </td>
# <td rowspan="2">16 MP
# </td>
# <td rowspan="2">Optical
# </td>
# <td rowspan="2">Yes
# </td></tr>
# <tr>
# <td>Realme 8 Pro
# </td>
# <td><a href="/wiki/List_of_Qualcomm_Snapdragon_processors" title="List of Qualcomm Snapdragon processors">Qualcomm Snapdragon 720G</a>
# </td>
# <td>Octa-core, (2x 2.30<span class="nowrap"> </span>GHz + 6x 1.80<span class="nowrap"> </span>GHz Kryo 465)
# </td>
# <td>Adreno 618
# </td>
# <td>6/8 GB
# </td>
# <td>160.6 x 73.9 x 8.1 mm
# </td>
# <td>176 g
# </td>
# <td>4500 mAh
# </td>
# <td>USB-C, <br/> 50 W
# </td>
# <td>108 MP (wide) + 8 MP (ultrawide) + 2 MP (macro) + 2 MP (depth)
# </td>
# <td>4K@30fps, 1080p@30/60/120/240/480fps, 720p@960fps
# </td></tr>
# <tr>
# <td>Meizu 18
# </td>
# <td rowspan="2"><a href="/wiki/List_of_Qualcomm_Snapdragon_processors" title="List of Qualcomm Snapdragon processors">Qualcomm Snapdragon 888</a>
# </td>
# <td rowspan="2">Octa-core, (1x 2.84<span class="nowrap"> </span>GHz + 3x 2.42<span class="nowrap"> </span>GHz + 4x 1.80<span class="nowrap"> </span>GHz Kryo 680)
# </td>
# <td rowspan="2">Adreno 660
# </td>
# <td rowspan="2">128/256 GB
# </td>
# <td rowspan="2">None
# </td>
# <td rowspan="2">8/12 GB
# </td>
# <td rowspan="2">Android 11
# </td>
# <td rowspan="2">Flyme 9
# </td>
# <td>152.4 x 69.2 x 8.2 mm
# </td>
# <td>162 g
# </td>
# <td>4000 mAh
# </td>
# <td>USB-C, <br/> 36 W
# </td>
# <td>6.2", 3200×1440, 120 Hz AMOLED
# </td>
# <td>64 MP (wide) + 8 MP (telephoto) + 16 MP (ultrawide)
# </td>
# <td>4K@30/60fps, 1080p
# </td>
# <td>20 MP
# </td>
# <td rowspan="2">Optical
# </td>
# <td rowspan="2">Yes
# </td></tr>
# <tr>
# <td>Meizu 18 Pro
# </td>
# <td>162.5 x 73 x 8.1 mm
# </td>
# <td>189 g
# </td>
# <td>4500 mAh
# </td>
# <td>USB-C, <br/> 40 W
# <p>Wireless, <br/> 40 W
# </p>
# </td>
# <td>6.7", 3200×1440, 120 Hz AMOLED
# </td>
# <td>50 MP (wide) + 8 MP (telephoto) + 32 MP (ultrawide)
# </td>
# <td>8K, 4K@30/60fps, 1080p
# </td>
# <td>44 MP
# </td></tr>
# <tr>
# <td>Vivo iQOO Neo5
# </td>
# <td><a href="/wiki/List_of_Qualcomm_Snapdragon_processors" title="List of Qualcomm Snapdragon processors">Qualcomm Snapdragon 870</a>
# </td>
# <td>Octa-core, (1x 3.2<span class="nowrap"> </span>GHz + 3x 2.42<span class="nowrap"> </span>GHz + 4x 1.80<span class="nowrap"> </span>GHz Kryo 585)
# </td>
# <td>Adreno 650
# </td>
# <td rowspan="2">128/256 GB
# </td>
# <td rowspan="5">None
# </td>
# <td rowspan="2">8/12 GB
# </td>
# <td rowspan="5">Android 11
# </td>
# <td rowspan="2">OriginOS
# </td>
# <td>163.3 x 76.4 x 8.4 mm
# </td>
# <td>196 g
# </td>
# <td>4400 mAh
# </td>
# <td>USB-C, <br/> 66 W
# </td>
# <td rowspan="2">6.62", 2400×1080, 120 Hz AMOLED
# </td>
# <td>48 MP (wide) + 13 MP (ultrawide) + 2 MP (depth)
# </td>
# <td rowspan="2">4K@30fps, 1080p@30fps
# </td>
# <td rowspan="2">16 MP
# </td>
# <td rowspan="5">Optical
# </td>
# <td rowspan="5">Yes
# </td></tr>
# <tr>
# <td>Vivo iQOO 7
# </td>
# <td><a href="/wiki/List_of_Qualcomm_Snapdragon_processors" title="List of Qualcomm Snapdragon processors">Qualcomm Snapdragon 888</a>
# </td>
# <td>Octa-core, (1x 2.84<span class="nowrap"> </span>GHz + 3x 2.42<span class="nowrap"> </span>GHz + 4x 1.80<span class="nowrap"> </span>GHz Kryo 680)
# </td>
# <td>Adreno 660
# </td>
# <td>162.2 x 75.8 x 8.7 mm
# </td>
# <td>210 g
# </td>
# <td>4000 mAh
# </td>
# <td>USB-C, <br/> 120 W
# </td>
# <td rowspan="3">48 MP (wide) + 13 MP (ultrawide) + 13 MP (portrait)
# </td></tr>
# <tr>
# <td><a href="/wiki/Vivo_X60" title="Vivo X60">Vivo X60</a>
# </td>
# <td rowspan="2"><a href="/wiki/List_of_Qualcomm_Snapdragon_processors" title="List of Qualcomm Snapdragon processors">Qualcomm Snapdragon 870</a>
# </td>
# <td rowspan="2">Octa-core, (1x 3.2<span class="nowrap"> </span>GHz + 3x 2.42<span class="nowrap"> </span>GHz + 4x 1.80<span class="nowrap"> </span>GHz Kryo 585)
# </td>
# <td rowspan="2">Adreno 650
# </td>
# <td rowspan="2">256 GB
# </td>
# <td rowspan="2">12 GB
# </td>
# <td rowspan="3">Funtouch 11.1
# </td>
# <td>159.6 x 75 x 7.4 mm
# </td>
# <td>176 g
# </td>
# <td>4300 mAh
# </td>
# <td rowspan="2">USB-C, <br/> 33 W
# </td>
# <td rowspan="3">6.56", 2376×1080, 120 Hz AMOLED
# </td>
# <td rowspan="2">4K@30/60fps, 1080p@30/60fps
# </td>
# <td rowspan="3">32 MP
# </td></tr>
# <tr>
# <td>Vivo X60 Pro
# </td>
# <td>158.6 x 73.2 x 7.6 mm
# </td>
# <td>179 g
# </td>
# <td rowspan="2">4200 mAh
# </td></tr>
# <tr>
# <td>Vivo X60 Pro+
# </td>
# <td><a href="/wiki/List_of_Qualcomm_Snapdragon_processors" title="List of Qualcomm Snapdragon processors">Qualcomm Snapdragon 888</a>
# </td>
# <td>Octa-core, (1x 2.84<span class="nowrap"> </span>GHz + 3x 2.42<span class="nowrap"> </span>GHz + 4x 1.80<span class="nowrap"> </span>GHz Kryo 680)
# </td>
# <td>Adreno 660
# </td>
# <td>128/256 GB
# </td>
# <td>8/12 GB
# </td>
# <td>158.6 x 73.4 x 9.1 mm
# </td>
# <td>191 g
# </td>
# <td>USB-C, <br/> 55 W
# </td>
# <td>50 MP (wide) + 32 MP (telephoto) + 48 MP (ultrawide) + 8 MP (telephoto)
# </td>
# <td>8K@30fps, 4K@30/60fps, 1080p@30/60fps
# </td></tr>
# <tr>
# <td>Asus <a href="/wiki/ROG_Phone_5" title="ROG Phone 5">ROG Phone 5</a>
# </td>
# <td rowspan="3"><a href="/wiki/List_of_Qualcomm_Snapdragon_processors" title="List of Qualcomm Snapdragon processors">Qualcomm Snapdragon 888</a>
# </td>
# <td rowspan="3">Octa-core, (1x 2.84<span class="nowrap"> </span>GHz + 3x 2.42<span class="nowrap"> </span>GHz + 4x 1.80<span class="nowrap"> </span>GHz Kryo 680)
# </td>
# <td rowspan="3">Adreno 660
# </td>
# <td>128/256 GB
# </td>
# <td rowspan="3">None
# </td>
# <td>8/12/16 GB
# </td>
# <td rowspan="3">Android 11
# </td>
# <td rowspan="3">ROG UI
# </td>
# <td rowspan="3">172.8 x 77.3 x 10.3 mm
# </td>
# <td rowspan="3">238 g
# </td>
# <td rowspan="3">6000 mAh
# </td>
# <td rowspan="3">USB-C, <br/> 65 W
# </td>
# <td rowspan="3">6.78", 2448×1080, 144 Hz AMOLED
# </td>
# <td rowspan="3">64 MP (wide) + 13 MP (ultrawide) + 5 MP (macro)
# </td>
# <td rowspan="3">8K@30fps, 4K@30/60/120fps, 1080p@30/60/120/240fps, 720p@480fps
# </td>
# <td rowspan="3">24 MP
# </td>
# <td rowspan="3">Optical
# </td>
# <td rowspan="3">Yes
# </td></tr>
# <tr>
# <td>Asus ROG Phone 5 Pro
# </td>
# <td rowspan="2">512 GB
# </td>
# <td>16 GB
# </td></tr>
# <tr>
# <td>Asus ROG Phone 5 Ultimate
# </td>
# <td>18 GB
# </td></tr>
# <tr>
# <td>Xiaomi Black Shark 4
# </td>
# <td><a href="/wiki/List_of_Qualcomm_Snapdragon_processors" title="List of Qualcomm Snapdragon processors">Qualcomm Snapdragon 870</a>
# </td>
# <td>Octa-core, (1x 3.2<span class="nowrap"> </span>GHz + 3x 2.42<span class="nowrap"> </span>GHz + 4x 1.80<span class="nowrap"> </span>GHz Kryo 585)
# </td>
# <td>Adreno 650
# </td>
# <td>128/256 GB
# </td>
# <td rowspan="2">None
# </td>
# <td>6/8/12 GB
# </td>
# <td rowspan="2">Android 11
# </td>
# <td rowspan="2">Joy UI 12.5
# </td>
# <td rowspan="2">163.8 x 76.4 x 9.9 mm
# </td>
# <td>210 g
# </td>
# <td rowspan="2">4500 mAh
# </td>
# <td rowspan="2">USB-C, <br/> 120 W
# </td>
# <td rowspan="2">6.67", 2400×1080, 144 Hz AMOLED
# </td>
# <td>48 MP (wide) + 8 MP (ultrawide) + 5 MP (macro)
# </td>
# <td rowspan="2">4K@30/60fps, 1080p@30/60/240/960fps
# </td>
# <td rowspan="2">20 MP
# </td>
# <td rowspan="2">Optical
# </td>
# <td rowspan="2">Yes
# </td></tr>
# <tr>
# <td>Xiaomi Black Shark 4 Pro
# </td>
# <td><a href="/wiki/List_of_Qualcomm_Snapdragon_processors" title="List of Qualcomm Snapdragon processors">Qualcomm Snapdragon 888</a>
# </td>
# <td>Octa-core, (1x 2.84<span class="nowrap"> </span>GHz + 3x 2.42<span class="nowrap"> </span>GHz + 4x 1.80<span class="nowrap"> </span>GHz Kryo 680)
# </td>
# <td>Adreno 660
# </td>
# <td>256/512 GB
# </td>
# <td>8/12/16 GB
# </td>
# <td>220 g
# </td>
# <td>64 MP (wide) + 8 MP (ultrawide) + 5 MP (macro)
# </td></tr>
# <tr>
# <td>ZTE Nubia Red Magic 6
# </td>
# <td rowspan="2"><a href="/wiki/List_of_Qualcomm_Snapdragon_processors" title="List of Qualcomm Snapdragon processors">Qualcomm Snapdragon 888</a>
# </td>
# <td rowspan="2">Octa-core, (1x 2.84<span class="nowrap"> </span>GHz + 3x 2.42<span class="nowrap"> </span>GHz + 4x 1.80<span class="nowrap"> </span>GHz Kryo 680)
# </td>
# <td rowspan="2">Adreno 660
# </td>
# <td>128/256 GB
# </td>
# <td rowspan="2">None
# </td>
# <td>8/12 GB
# </td>
# <td rowspan="2">Android 11
# </td>
# <td rowspan="2">Redmagic 4.0
# </td>
# <td rowspan="2">169.2 x 77.2 x 9.7 mm
# </td>
# <td rowspan="2">220 g
# </td>
# <td>5050 mAh
# </td>
# <td>USB-C, <br/> 66 W
# </td>
# <td rowspan="2">6.8", 2400×1080, 165 Hz AMOLED
# </td>
# <td rowspan="2">64 MP (wide) + 8 MP (ultrawide) + 2 MP (macro)
# </td>
# <td rowspan="2">8K@30fps, 4K@30/60fps, 1080p@30/60/120/240fps
# </td>
# <td rowspan="2">8 MP
# </td>
# <td rowspan="2">Optical
# </td>
# <td rowspan="2">Yes
# </td></tr>
# <tr>
# <td>ZTE Nubia Red Magic 6 Pro
# </td>
# <td>128/256/512 GB
# </td>
# <td>12/16/18 GB
# </td>
# <td>4500 mAh
# </td>
# <td>USB-C, <br/> 66 W / 120 W
# </td></tr></tbody></table>

# %%
# Number of columns in the table
for row in right_table.find("tr"):
    cells = row.findAll('td')

len(cells)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-cb76396e6aa3> in <module>
#       1 # Number of columns in the table
# ----> 2 for row in right_table.find("tr"):
#       3     cells = row.findAll('td')
#       4
#       5 len(cells)
#
# ~\Anaconda3\envs\tf_nptel\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2159         """Raise a helpful exception to explain a common code fix."""
#    2160         raise AttributeError(
# -> 2161             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2162         )
#
# AttributeError: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
# number of rows in the table including header
rows = right_table.find("tr")
len(rows)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-eb925ca7e6f4> in <module>
#       1 # number of rows in the table including header
# ----> 2 rows = right_table.find("tr")
#       3 len(rows)
#
# ~\Anaconda3\envs\tf_nptel\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2159         """Raise a helpful exception to explain a common code fix."""
#    2160         raise AttributeError(
# -> 2161             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2162         )
#
# AttributeError: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
# select also works as find_all
lst_data1 = []
for row in rows[1:]:
            data = [d.text.rstrip() for d in row.select('td')]
            lst_data1.append(data)

# %%
for i in lst_data1:
    for index, j in enumerate(i):
        if index == 0:
            print(j)
# Out:
# Huawei nova 8 5G
# Huawei nova 8 Pro 5G
# Honor V40
# Oppo Find X3 Neo
# Oppo Find X3
# Oppo Find X3 Pro
# OnePlus 9
# OnePlus 9 Pro
# Realme GT 5G
# Moto G100
# Samsung Galaxy S21
# Samsung Galaxy S21+
# Samsung Galaxy S21 Ultra
# Xiaomi Mi 11
# Xiaomi Mi 11 Pro
# Xiaomi Mi 11 Ultra
# Redmi K40
# Redmi K40 Pro
# Redmi K40 Pro+
# Redmi Note 10
# Redmi Note 10S
# Redmi Note 10 5G
# Redmi Note 10 Pro
# Realme 8
# Realme 8 Pro
# Meizu 18
# Meizu 18 Pro
# Vivo iQOO Neo5
# Vivo iQOO 7
# Vivo X60
# Vivo X60 Pro
# Vivo X60 Pro+
# Asus ROG Phone 5
# Asus ROG Phone 5 Pro
# Asus ROG Phone 5 Ultimate
# Xiaomi Black Shark 4
# Xiaomi Black Shark 4 Pro
# ZTE Nubia Red Magic 6
# ZTE Nubia Red Magic 6 Pro
